# %%
# Add Matplotlib inline magic command
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Files to load
merged = r"C:\Users\Kobers\Desktop\Class Folder\Untitled Folder\merged.csv"
EV = r"C:\Users\Kobers\Desktop\Class Folder\Untitled Folder\EV_data.csv"

# %%
# Read the data file and store it in a pandas DataFrame.
merged_df = pd.read_csv(merged)
merged_df.head(10)
# Out:
#    Unnamed: 0  Entity  Year  Fossil fuels (% electricity)  \
# 0           0  Africa  2000                     78.745171
# 1           1  Africa  2001                     79.025871
# 2           2  Africa  2002                     79.125481
# 3           3  Africa  2003                     80.062469
# 4           4  Africa  2004                     80.044159
# 5           5  Africa  2005                     80.852448
# 6           6  Africa  2006                     81.177032
# 7           7  Africa  2007                     81.255211
# 8           8  Africa  2008                     81.099655
# 9           9  Africa  2009                     80.767754
#
#    Renewables (% electricity)  Per capita electricity (kWh)  \
# 0                   17.654526                    542.776917
# 1                   18.216648                    552.547424
# 2                   18.001900                    572.745850
# 3                   16.845776                    583.601562
# ...

# %%
# Read the data file and store it in a pandas DataFrame.
EV_df = pd.read_csv(EV)
EV_df.head(10)
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2  Petrol Unnamed: 4 Adv Petrol Unnamed: 6  \
# 0     Entity       Year       Econ     Mid        Lux       Econ        Mid
# 1    Belgium       2004     0.2578  0.1893     0.0516          0          0
# 2    Belgium       2005     0.2613  0.1749      0.044          0          0
# 3    Belgium       2006      0.255  0.1612     0.0401          0          0
# 4    Belgium       2007     0.2481  0.1487     0.0368          0          0
# 5    Belgium       2008     0.2402  0.1359      0.034          0          0
# 6    Belgium       2009     0.2338  0.1263     0.0319          0          0
# 7    Belgium       2010     0.2279  0.1173     0.0302          0          0
# 8    Belgium       2011     0.1392  0.1936     0.0283          0          0
# 9    Belgium       2012     0.1349  0.1928     0.0272          0          0
#
#   Unnamed: 7  Diesel Unnamed: 9  ... Unnamed: 44 Unnamed: 45 Unnamed: 46  \
# ...

# %%
merged_df.describe()
# Out:
#         Unnamed: 0         Year  Fossil fuels (% electricity)  \
# count  1740.000000  1740.000000                   1740.000000
# mean    869.500000  2009.500000                     62.850019
# std     502.439051     5.767939                     27.530044
# min       0.000000  2000.000000                      0.000000
# 25%     434.750000  2004.750000                     43.483808
# 50%     869.500000  2009.500000                     66.995457
# 75%    1304.250000  2014.250000                     87.163334
# max    1739.000000  2019.000000                    112.454361
#
#        Renewables (% electricity)  Per capita electricity (kWh)  \
# count                 1740.000000                   1740.000000
# mean                    24.608029                   6206.736997
# std                     24.417342                   6517.081923
# min                      0.000000                    123.541161
# 25%                      7.023677                   2401.610901
# ...

# %%
merged_df = merged_df.drop(['Unnamed: 0'], axis=1)

# %%
merged_df = merged_df.set_index(['Entity','Year'])

# %%
merged_df.head(20)
# Out:
#              Fossil fuels (% electricity)  Renewables (% electricity)  \
# Entity Year
# Africa 2000                     78.745171                   17.654526
#        2001                     79.025871                   18.216648
#        2002                     79.125481                   18.001900
#        2003                     80.062469                   16.845776
#        2004                     80.044159                   16.825420
#        2005                     80.852448                   16.532818
#        2006                     81.177032                   16.498602
#        2007                     81.255211                   16.277168
#        2008                     81.099655                   16.296865
#        2009                     80.767754                   16.633482
#        2010                     80.486969                   16.941187
#        2011                     80.311188                   17.035776
# ...

# %%
merged_df.describe()
# Out:
#        Fossil fuels (% electricity)  Renewables (% electricity)  \
# count                   1740.000000                 1740.000000
# mean                      62.850019                   24.608029
# std                       27.530044                   24.417342
# min                        0.000000                    0.000000
# 25%                       43.483808                    7.023677
# 50%                       66.995457                   16.241909
# 75%                       87.163334                   33.525917
# max                      112.454361                   99.990532
#
#        Per capita electricity (kWh)  \
# count                   1740.000000
# mean                    6206.736997
# std                     6517.081923
# min                      123.541161
# 25%                     2401.610901
# 50%                     4760.040039
# 75%                     7998.775024
# max                    58889.703125
#
# ...

# %%
describe_df = merged_df.describe()

# %%
describe_df["Fossil fuels (% electricity)"]
# Out:
# count    1740.000000
# mean       62.850019
# std        27.530044
# min         0.000000
# 25%        43.483808
# 50%        66.995457
# 75%        87.163334
# max       112.454361
# Name: Fossil fuels (% electricity), dtype: float64

# %%
describe_df["Renewables (% electricity)"]
# Out:
# count    1740.000000
# mean       24.608029
# std        24.417342
# min         0.000000
# 25%         7.023677
# 50%        16.241909
# 75%        33.525917
# max        99.990532
# Name: Renewables (% electricity), dtype: float64

# %%
describe_df.boxplot(by=['Fossil fuels (% electricity)'],rot=90,boxprops=dict(color='green'))
# Out:
# array([[<AxesSubplot:title={'center':'Agriculture (per capita)'}, xlabel='[Fossil fuels (% electricity)]'>,
#         <AxesSubplot:title={'center':'Aviation and shipping (per capita)'}, xlabel='[Fossil fuels (% electricity)]'>,
#         <AxesSubplot:title={'center':'Biofuels Consumption - TWh - Total (zero filled)'}, xlabel='[Fossil fuels (% electricity)]'>,
#         <AxesSubplot:title={'center':'Buildings (per capita)'}, xlabel='[Fossil fuels (% electricity)]'>,
#         <AxesSubplot:title={'center':'Carbon intensity of electricity (gCO2/kWh)'}, xlabel='[Fossil fuels (% electricity)]'>],
#        [<AxesSubplot:title={'center':'Coal Consumption - TWh (zero filled)'}, xlabel='[Fossil fuels (% electricity)]'>,
#         <AxesSubplot:title={'center':'Electricity and heat (per capita)'}, xlabel='[Fossil fuels (% electricity)]'>,
#         <AxesSubplot:title={'center':'Fossil fuels (% equivalent primary energy)'}, xlabel='[Fossil fuels (% electricity)]'>,
# ...

# %%
describe_df.boxplot['Fossil fuels (% electricity)']
# Out:
#   File "C:\Users\Kobers\AppData\Local\Temp/ipykernel_1512/1212840708.py", line 1
#     describe_df.boxplot[by='Fossil fuels (% electricity)']
#                           ^
# SyntaxError: invalid syntax
